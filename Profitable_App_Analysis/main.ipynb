# %% [markdown]
# Profitable Mobile App Analysis

# %% [markdown]
# This project is a look into different mobile applications, their categories, and how profitable or how profitable it may be to run ads within the application.
#
# This project looks at data from

# %%
import sklearn
import pandas as pd
import seaborn
import numpy

# %%
df = pd.read_csv('google_play_store_dataset.csv')

df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# The more important data from this file I want to look at is the app Installs. I want to break this down into specific categories and look at each individual app and its installs to extimate a potential profit.

# %% [markdown]
# Removing rows with nan or incorrect data like App ratings over 5.0 which does no exist on the Google Play store. Also removing duplicate app records from the dataframe.

# %%
df.dropna(subset=['Rating'], inplace=True)
df.drop_duplicates(subset=['App'], inplace=True)
df.drop(df[df['Rating'] > 5.0].index, inplace=True)

print(len(df))
df.head()
# Out:
# 8196
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# I wanted to have a record of the available app categories from the dataset.

# %%
print(df['Category'].unique())
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
categories = df['Category'].unique()
ad = df[df['Category'] == 'ART_AND_DESIGN']
av = df[df['Category'] == 'AUTO_AND_VEHICLE']
bea = df[df['Category'] == 'BEAUTY']
br = df[df['Category'] == 'BOOKS_AND_REFERENCE']
bus =df[df['Category'] == 'BUSINESS']
comics = df[df['Category'] == 'COMICS']
comm = df[df['Category'] == 'COMMUNICATION']
dating = df[df['Category'] == 'DATING']
edu = df[df['Category'] == 'EDUCATION']
enrtn = df[df['Category'] == 'ENTERTAINMENT']
evnt = df[df['Category'] == 'EVENTS']
fin = df[df['Category'] == 'FINANCE']
fd = df[df['Category'] == 'FOOD_AND_DRINK']
hf = df[df['Category'] == 'HEALTH_AND_FITNESS']
home = df[df['Category'] == 'HOUSE_AND_HOME']
libr = df[df['Category'] == 'LIBRARIES_AND_DEMO']
life = df[df['Category'] == 'LIFESTYLE']
gm = df[df['Category'] == 'GAME']
fam = df[df['Category'] == 'FAMILY']
med = df[df['Category'] == 'MEDICAL']
soc = df[df['Category'] == 'SOCIAL']
shop = df[df['Category'] == 'SHOPPING']
photo = df[df['Category'] == 'PHOTOGRAPHY']
travel = df[df['Category'] == 'TRAVEL_AND_LOCAL']
tools = df[df['Category'] == 'TOOLS']
prsnal = df[df['Category'] == 'PERSONALIZATION']
prod = df[df['Category'] == 'PRODUCTIVITY']
parent = df[df['Category'] == 'PARENTING']
weather = df[df['Category'] == 'WEATHER']
vid_p = df[df['Category'] == 'VIDEO_PLAYERS']
news = df[df['Category'] == 'NEWS_AND_MAGAZINES']
maps = df[df['Category'] == 'MAPS_AND_NAVIGATION']

df_2 = pd.DataFrame()

print(gm)

ad_df.loc[(ad_df['Installs'] == '10,000+') | (ad_df['Installs'] == '50,000+') | (ad_df['Installs'] == '500,000+')]
# Out:
#                                 App Category  Rating   Reviews Size  \
# 1653                         ROBLOX     GAME     4.5   4447388  67M
# 1654                 Subway Surfers     GAME     4.5  27722264  76M
# 1655               Candy Crush Saga     GAME     4.4  22426677  74M
# 1656                      Solitaire     GAME     4.7    254258  23M
# 1657                 Bubble Shooter     GAME     4.5    148897  46M
# ...                             ...      ...     ...       ...  ...
# 10791             Winter Wonderland     GAME     4.0      1287  38M
# 10792        Soccer Clubs Logo Quiz     GAME     4.2     21661  16M
# 10793                     Sid Story     GAME     4.4     28510  78M
# 10803  Fatal Raid - No.1 Mobile FPS     GAME     4.3     56496  81M
# 10804                  Poker Pro.Fr     GAME     4.2      5442  17M
#
#              Installs  Type Price Content Rating  \
# 1653     100,000,000+  Free     0   Everyone 10+
# ...
