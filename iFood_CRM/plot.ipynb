# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plot
from datetime import date
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

# %%
file = pd.read_csv("new_ifood_df.csv")
file.head()
# Out:
#    Unnamed: 0  ID  Income  Age Education Status Marital Status  Kidhome  \
# 0           0   0   58138   63       Graduation         Single        0
# 1           1   1   46344   66       Graduation         Single        1
# 2           2   2   71613   55       Graduation       Together        0
# 3           3   3   26646   36       Graduation       Together        1
# 4           4   4   58293   39              PhD        Married        1
#
#    Teenhome  Recency  MntWines  ...  AcceptedCmp1  AcceptedCmp2  Complain  \
# 0         0       58       635  ...             0             0         0
# 1         1       38        11  ...             0             0         0
# 2         0       26       426  ...             0             0         0
# 3         0       26        11  ...             0             0         0
# 4         0       94       173  ...             0             0         0
#
#    Z_CostContact  Z_Revenue  Response  Customer_Days  MntTotal  \
# 0              3         11         1           2822      1529
# 1              3         11         0           2272        21
# 2              3         11         0           2471       734
# 3              3         11         0           2298        48
# 4              3         11         0           2320       407
#
#    MntRegularProds  AcceptedCmpOverall
# 0             1441                   0
# 1               15                   0
# 2              692                   0
# 3               43                   0
# 4              392                   0
#
# [5 rows x 33 columns]

# %%
df = pd.DataFrame(file)

fig, x_ax = plot.subplots(1,3, figsize=(15,4))

sbn.countplot(file['Marital Status'], ax=x_ax[0])
sbn.countplot(file['Education Status'], ax=x_ax[1])

plt = file.groupby(['Marital Status', 'Education Status']).size().reset_index().pivot(columns='Marital Status', index='Education Status', values=0)
plt.apply(lambda x: x/x.sum(), axis=1).plot(kind='bar', stacked=True, ax=x_ax[2], colormap='Paired')

plot.legend(loc='center left', bbox_to_anchor=(1.0,0.5))
plot.tight_layout()

fig.show()
# Out:
# C:\Users\gosho\AppData\Local\Temp\ipykernel_18048\3487172414.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
file
# Out:
#       Unnamed: 0    ID  Income  Age Education Status Marital Status  Kidhome  \
# 0              0     0   58138   63       Graduation         Single        0
# 1              1     1   46344   66       Graduation         Single        1
# 2              2     2   71613   55       Graduation       Together        0
# 3              3     3   26646   36       Graduation       Together        1
# 4              4     4   58293   39              PhD        Married        1
# ...          ...   ...     ...  ...              ...            ...      ...
# 2200        2200  2200   61223   53       Graduation        Married        0
# 2201        2201  2201   64014   74              PhD       Together        2
# 2202        2202  2202   56981   39       Graduation       Divorced        0
# 2203        2203  2203   69245   64           Master       Together        0
# 2204        2204  2204   52869   66              PhD        Married        1
#
#       Teenhome  Recency  MntWines  ...  AcceptedCmp1  AcceptedCmp2  Complain  \
# 0            0       58       635  ...             0             0         0
# 1            1       38        11  ...             0             0         0
# 2            0       26       426  ...             0             0         0
# 3            0       26        11  ...             0             0         0
# 4            0       94       173  ...             0             0         0
# ...        ...      ...       ...  ...           ...           ...       ...
# 2200         1       46       709  ...             0             0         0
# 2201         1       56       406  ...             1             0         0
# 2202         0       91       908  ...             0             0         0
# 2203         1        8       428  ...             0             0         0
# 2204         1       40        84  ...             0             0         0
#
#       Z_CostContact  Z_Revenue  Response  Customer_Days  MntTotal  \
# 0                 3         11         1           2822      1529
# 1                 3         11         0           2272        21
# 2                 3         11         0           2471       734
# 3                 3         11         0           2298        48
# 4                 3         11         0           2320       407
# ...             ...        ...       ...            ...       ...
# 2200              3         11         0           2540      1094
# 2201              3         11         0           2178       436
# 2202              3         11         0           2314      1217
# 2203              3         11         0           2315       782
# 2204              3         11         1           2781       151
#
#       MntRegularProds  AcceptedCmpOverall
# 0                1441                   0
# 1                  15                   0
# 2                 692                   0
# 3                  43                   0
# 4                 392                   0
# ...               ...                 ...
# 2200              847                   0
# 2201              428                   1
# 2202             1193                   1
# 2203              721                   0
# 2204              130                   0
#
# [2205 rows x 33 columns]

# %% [markdown]
# show percentage of web visits that turned into possible purchases?
#
# - is there a correlations between income and purchases? Where the purchases are made? What is purchased?
#
# - does education or marital status affect anything?

# %%
col_to_move = df.pop('Age')
df.insert(2, 'Age', col_to_move)

df.to_csv('new_ifood_df.csv')

# %%
col_to_move = df.pop('education_Status')
df.insert(3, 'Education Status', col_to_move)
# Out:
# KeyboardInterrupt

# %%
df.to_csv('new_ifood_df.csv')

# %%
col_to_move = df.pop('marital_Status')
df.insert(4, 'Marital Status', col_to_move)

df.to_csv('new_ifood_df.csv')

# %%
df['AcceptedCmp1'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2200    0
# 2201    1
# 2202    0
# 2203    0
# 2204    0
# Name: AcceptedCmp1, Length: 2205, dtype: int64>

# %%
'''count = 0;
for i in df['AcceptedCmp1']:
    if i == 1 or i == '1':
        count += 1


print(count)'''
# Out:
# 142

# %%
row_list = []

d = {}


new_df = pd.DataFrame()

new_df = df[(df[['Kidhome', 'Teenhome']] >= 1).all(axis=1)]

print(new_df)
# Out:
#       Unnamed: 0    ID  Age  Income Education Status Marital Status  Kidhome  \
# 1              1     1   66   46344       Graduation         Single        1
# 9              9     9   70    5648              PhD       Together        1
# 12            12    12   68   59354           Master       Divorced        1
# 15            15    15   40   41850       Graduation        Married        1
# 25            25    25   44   53359       Graduation        Married        1
# ...          ...   ...  ...     ...              ...            ...      ...
# 2190        2190  2190   57   33562           Master        Married        1
# 2192        2192  2192   52   58554       Graduation       Together        1
# 2193        2193  2193   41   63777       Graduation        Married        1
# 2201        2201  2201   74   64014              PhD       Together        2
# 2204        2204  2204   66   52869              PhD        Married        1
#
#       Teenhome  Recency  MntWines  ...  AcceptedCmp1  AcceptedCmp2  Complain  \
# 1            1       38        11  ...             0             0         0
# 9            1       68        28  ...             0             0         0
# 12           1       53       233  ...             0             0         0
# 15           1       51        53  ...             0             0         0
# 25           1        4       173  ...             0             0         0
# ...        ...      ...       ...  ...           ...           ...       ...
# 2190         2       33        21  ...             0             0         0
# 2192         1       55       368  ...             0             0         0
# 2193         1       87       457  ...             0             0         0
# 2201         1       56       406  ...             1             0         0
# 2204         1       40        84  ...             0             0         0
#
#       Z_CostContact  Z_Revenue  Response  Customer_Days  MntTotal  \
# 1                 3         11         0           2272        21
# 9                 3         11         0           2267        36
# 12                3         11         0           2385       296
# 15                3         11         0           2711        92
# 25                3         11         0           2557       216
# ...             ...        ...       ...            ...       ...
# 2190              3         11         0           2163        48
# 2192              3         11         0           2800       498
# 2193              3         11         0           2621       600
# 2201              3         11         0           2178       436
# 2204              3         11         1           2781       151
#
#       MntRegularProds  AcceptedCmpOverall
# 1                  15                   0
# 9                  23                   1
# 12                282                   0
# 15                 88                   0
# 25                175                   0
# ...               ...                 ...
# 2190               45                   0
# 2192              410                   0
# 2193              547                   0
# 2201              428                   1
# 2204              130                   0
#
# [418 rows x 33 columns]

# %%
row_list = []

d = {}


df['Education Status'] = df['Education Status'].astype('str')



for index, row in df.iterrows():
    if df['Education Status'].str.contains('PhD').any() or df['Education Status'].str.contains('Master').any() or df['Education Status'].str.contains('Graduation').any():
# Out:
# ID                              0
# Income                      58138
# Age                            63
# Education Status       Graduation
# Marital Status             Single
# Kidhome                         0
# Teenhome                        0
# Recency                        58
# MntWines                      635
# MntFruits                      88
# MntMeatProducts               546
# MntFishProducts               172
# MntSweetProducts               88
# MntGoldProds                   88
# NumDealsPurchases               3
# NumWebPurchases                 8
# NumCatalogPurchases            10
# NumStorePurchases               4
# NumWebVisitsMonth               7
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        1
# Customer_Days                2822
# MntTotal                     1529
# MntRegularProds              1441
# AcceptedCmpOverall              0
# Name: 0, dtype: object
# ID                              1
# Income                      46344
# Age                            66
# Education Status       Graduation
# Marital Status             Single
# Kidhome                         1
# Teenhome                        1
# Recency                        38
# MntWines                       11
# MntFruits                       1
# MntMeatProducts                 6
# MntFishProducts                 2
# MntSweetProducts                1
# MntGoldProds                    6
# NumDealsPurchases               2
# NumWebPurchases                 1
# NumCatalogPurchases             1
# NumStorePurchases               2
# NumWebVisitsMonth               5
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2272
# MntTotal                       21
# MntRegularProds                15
# AcceptedCmpOverall              0
# Name: 1, dtype: object
# ID                              2
# Income                      71613
# Age                            55
# Education Status       Graduation
# Marital Status           Together
# Kidhome                         0
# Teenhome                        0
# Recency                        26
# MntWines                      426
# MntFruits                      49
# MntMeatProducts               127
# MntFishProducts               111
# MntSweetProducts               21
# MntGoldProds                   42
# NumDealsPurchases               1
# NumWebPurchases                 8
# NumCatalogPurchases             2
# NumStorePurchases              10
# NumWebVisitsMonth               4
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2471
# MntTotal                      734
# MntRegularProds               692
# AcceptedCmpOverall              0
# Name: 2, dtype: object
# ID                              3
# Income                      26646
# Age                            36
# Education Status       Graduation
# Marital Status           Together
# Kidhome                         1
# Teenhome                        0
# Recency                        26
# MntWines                       11
# MntFruits                       4
# MntMeatProducts                20
# MntFishProducts                10
# MntSweetProducts                3
# MntGoldProds                    5
# NumDealsPurchases               2
# NumWebPurchases                 2
# NumCatalogPurchases             0
# NumStorePurchases               4
# NumWebVisitsMonth               6
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2298
# MntTotal                       48
# MntRegularProds                43
# AcceptedCmpOverall              0
# Name: 3, dtype: object
# ID                           4
# Income                   58293
# Age                         39
# Education Status           PhD
# Marital Status         Married
# Kidhome                      1
# Teenhome                     0
# Recency                     94
# MntWines                   173
# MntFruits                   43
# MntMeatProducts            118
# MntFishProducts             46
# MntSweetProducts            27
# MntGoldProds                15
# NumDealsPurchases            5
# NumWebPurchases              5
# NumCatalogPurchases          3
# NumStorePurchases            6
# NumWebVisitsMonth            5
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2320
# MntTotal                   407
# MntRegularProds            392
# AcceptedCmpOverall           0
# Name: 4, dtype: object
# ID                            5
# Income                    62513
# Age                          53
# Education Status         Master
# Marital Status         Together
# Kidhome                       0
# Teenhome                      1
# Recency                      16
# MntWines                    520
# MntFruits                    42
# MntMeatProducts              98
# MntFishProducts               0
# MntSweetProducts             42
# MntGoldProds                 14
# NumDealsPurchases             2
# NumWebPurchases               6
# NumCatalogPurchases           4
# NumStorePurchases            10
# NumWebVisitsMonth             6
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2452
# MntTotal                    702
# MntRegularProds             688
# AcceptedCmpOverall            0
# Name: 5, dtype: object
# ID                              6
# Income                      55635
# Age                            49
# Education Status       Graduation
# Marital Status           Divorced
# Kidhome                         0
# Teenhome                        1
# Recency                        34
# MntWines                      235
# MntFruits                      65
# MntMeatProducts               164
# MntFishProducts                50
# MntSweetProducts               49
# MntGoldProds                   27
# NumDealsPurchases               4
# NumWebPurchases                 7
# NumCatalogPurchases             3
# NumStorePurchases               7
# NumWebVisitsMonth               6
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2752
# MntTotal                      563
# MntRegularProds               536
# AcceptedCmpOverall              0
# Name: 6, dtype: object
# ID                           7
# Income                   33454
# Age                         35
# Education Status           PhD
# Marital Status         Married
# Kidhome                      1
# Teenhome                     0
# Recency                     32
# MntWines                    76
# MntFruits                   10
# MntMeatProducts             56
# MntFishProducts              3
# MntSweetProducts             1
# MntGoldProds                23
# NumDealsPurchases            2
# NumWebPurchases              4
# NumCatalogPurchases          0
# NumStorePurchases            4
# NumWebVisitsMonth            8
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2576
# MntTotal                   146
# MntRegularProds            123
# AcceptedCmpOverall           0
# Name: 7, dtype: object
# ID                            8
# Income                    30351
# Age                          46
# Education Status            PhD
# Marital Status         Together
# Kidhome                       1
# Teenhome                      0
# Recency                      19
# MntWines                     14
# MntFruits                     0
# MntMeatProducts              24
# MntFishProducts               3
# MntSweetProducts              3
# MntGoldProds                  2
# NumDealsPurchases             1
# NumWebPurchases               3
# NumCatalogPurchases           0
# NumStorePurchases             2
# NumWebVisitsMonth             9
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      1
# Customer_Days              2547
# MntTotal                     44
# MntRegularProds              42
# AcceptedCmpOverall            0
# Name: 8, dtype: object
# ID                            9
# Income                     5648
# Age                          70
# Education Status            PhD
# Marital Status         Together
# Kidhome                       1
# Teenhome                      1
# Recency                      68
# MntWines                     28
# MntFruits                     0
# MntMeatProducts               6
# MntFishProducts               1
# MntSweetProducts              1
# MntGoldProds                 13
# NumDealsPurchases             1
# NumWebPurchases               1
# NumCatalogPurchases           0
# NumStorePurchases             0
# NumWebVisitsMonth            20
# AcceptedCmp3                  1
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2267
# MntTotal                     36
# MntRegularProds              23
# AcceptedCmpOverall            1
# Name: 9, dtype: object
# ID                          10
# Income                    7500
# Age                         44
# Education Status         Basic
# Marital Status         Married
# Kidhome                      0
# Teenhome                     0
# Recency                     59
# MntWines                     6
# MntFruits                   16
# MntMeatProducts             11
# MntFishProducts             11
# MntSweetProducts             1
# MntGoldProds                16
# NumDealsPurchases            1
# NumWebPurchases              2
# NumCatalogPurchases          0
# NumStorePurchases            3
# NumWebVisitsMonth            8
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2752
# MntTotal                    45
# MntRegularProds             29
# AcceptedCmpOverall           0
# Name: 10, dtype: object
# ID                             11
# Income                      63033
# Age                            61
# Education Status       Graduation
# Marital Status           Divorced
# Kidhome                         0
# Teenhome                        0
# Recency                        82
# MntWines                      194
# MntFruits                      61
# MntMeatProducts               480
# MntFishProducts               225
# MntSweetProducts              112
# MntGoldProds                   30
# NumDealsPurchases               1
# NumWebPurchases                 3
# NumCatalogPurchases             4
# NumStorePurchases               8
# NumWebVisitsMonth               2
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2385
# MntTotal                     1072
# MntRegularProds              1042
# AcceptedCmpOverall              0
# Name: 11, dtype: object
# ID                           12
# Income                    59354
# Age                          68
# Education Status         Master
# Marital Status         Divorced
# Kidhome                       1
# Teenhome                      1
# Recency                      53
# MntWines                    233
# MntFruits                     2
# MntMeatProducts              53
# MntFishProducts               3
# MntSweetProducts              5
# MntGoldProds                 14
# NumDealsPurchases             3
# NumWebPurchases               6
# NumCatalogPurchases           1
# NumStorePurchases             5
# NumWebVisitsMonth             6
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2385
# MntTotal                    296
# MntRegularProds             282
# AcceptedCmpOverall            0
# Name: 12, dtype: object
# ID                             13
# Income                      17323
# Age                            33
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         0
# Teenhome                        0
# Recency                        38
# MntWines                        3
# MntFruits                      14
# MntMeatProducts                17
# MntFishProducts                 6
# MntSweetProducts                1
# MntGoldProds                    5
# NumDealsPurchases               1
# NumWebPurchases                 1
# NumCatalogPurchases             0
# NumStorePurchases               3
# NumWebVisitsMonth               8
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2786
# MntTotal                       41
# MntRegularProds                36
# AcceptedCmpOverall              0
# Name: 13, dtype: object
# ID                         14
# Income                  82800
# Age                        74
# Education Status          PhD
# Marital Status         Single
# Kidhome                     0
# Teenhome                    0
# Recency                    23
# MntWines                 1006
# MntFruits                  22
# MntMeatProducts           115
# MntFishProducts            59
# MntSweetProducts           68
# MntGoldProds               45
# NumDealsPurchases           1
# NumWebPurchases             7
# NumCatalogPurchases         6
# NumStorePurchases          12
# NumWebVisitsMonth           3
# AcceptedCmp3                0
# AcceptedCmp4                0
# AcceptedCmp5                1
# AcceptedCmp1                1
# AcceptedCmp2                0
# Complain                    0
# Z_CostContact               3
# Z_Revenue                  11
# Response                    1
# Customer_Days            2741
# MntTotal                 1270
# MntRegularProds          1225
# AcceptedCmpOverall          2
# Name: 14, dtype: object
# ID                             15
# Income                      41850
# Age                            40
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         1
# Teenhome                        1
# Recency                        51
# MntWines                       53
# MntFruits                       5
# MntMeatProducts                19
# MntFishProducts                 2
# MntSweetProducts               13
# MntGoldProds                    4
# NumDealsPurchases               3
# NumWebPurchases                 3
# NumCatalogPurchases             0
# NumStorePurchases               3
# NumWebVisitsMonth               8
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2711
# MntTotal                       92
# MntRegularProds                88
# AcceptedCmpOverall              0
# Name: 15, dtype: object
# ID                             16
# Income                      37760
# Age                            74
# Education Status       Graduation
# Marital Status           Together
# Kidhome                         0
# Teenhome                        0
# Recency                        20
# MntWines                       84
# MntFruits                       5
# MntMeatProducts                38
# MntFishProducts               150
# MntSweetProducts               12
# MntGoldProds                   28
# NumDealsPurchases               2
# NumWebPurchases                 4
# NumCatalogPurchases             1
# NumStorePurchases               6
# NumWebVisitsMonth               7
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2826
# MntTotal                      289
# MntRegularProds               261
# AcceptedCmpOverall              0
# Name: 16, dtype: object
# ID                          17
# Income                   76995
# Age                         71
# Education Status        Master
# Marital Status         Married
# Kidhome                      0
# Teenhome                     1
# Recency                     91
# MntWines                  1012
# MntFruits                   80
# MntMeatProducts            498
# MntFishProducts              0
# MntSweetProducts            16
# MntGoldProds               176
# NumDealsPurchases            2
# NumWebPurchases             11
# NumCatalogPurchases          4
# NumStorePurchases            9
# NumWebVisitsMonth            5
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 1
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2617
# MntTotal                  1606
# MntRegularProds           1430
# AcceptedCmpOverall           1
# Name: 17, dtype: object
# ID                           18
# Income                    33812
# Age                          35
# Education Status       2n Cycle
# Marital Status           Single
# Kidhome                       1
# Teenhome                      0
# Recency                      86
# MntWines                      4
# MntFruits                    17
# MntMeatProducts              19
# MntFishProducts              30
# MntSweetProducts             24
# MntGoldProds                 39
# NumDealsPurchases             2
# NumWebPurchases               2
# NumCatalogPurchases           1
# NumStorePurchases             3
# NumWebVisitsMonth             6
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2762
# MntTotal                     94
# MntRegularProds              55
# AcceptedCmpOverall            0
# Name: 18, dtype: object
# ID                             19
# Income                      37040
# Age                            38
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         0
# Teenhome                        0
# Recency                        41
# MntWines                       86
# MntFruits                       2
# MntMeatProducts                73
# MntFishProducts                69
# MntSweetProducts               38
# MntGoldProds                   48
# NumDealsPurchases               1
# NumWebPurchases                 4
# NumCatalogPurchases             2
# NumStorePurchases               5
# NumWebVisitsMonth               8
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2849
# MntTotal                      268
# MntRegularProds               220
# AcceptedCmpOverall              0
# Name: 19, dtype: object
# ID                             20
# Income                       2447
# Age                            41
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         1
# Teenhome                        0
# Recency                        42
# MntWines                        1
# MntFruits                       1
# MntMeatProducts              1725
# MntFishProducts                 1
# MntSweetProducts                1
# MntGoldProds                    1
# NumDealsPurchases              15
# NumWebPurchases                 0
# NumCatalogPurchases            28
# NumStorePurchases               0
# NumWebVisitsMonth               1
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2698
# MntTotal                     1729
# MntRegularProds              1728
# AcceptedCmpOverall              0
# Name: 20, dtype: object
# ID                          21
# Income                   58607
# Age                         71
# Education Status           PhD
# Marital Status         Married
# Kidhome                      0
# Teenhome                     1
# Recency                     63
# MntWines                   867
# MntFruits                    0
# MntMeatProducts             86
# MntFishProducts              0
# MntSweetProducts             0
# MntGoldProds                19
# NumDealsPurchases            3
# NumWebPurchases              2
# NumCatalogPurchases          3
# NumStorePurchases            9
# NumWebVisitsMonth            8
# AcceptedCmp3                 0
# AcceptedCmp4                 1
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2712
# MntTotal                   953
# MntRegularProds            934
# AcceptedCmpOverall           1
# Name: 21, dtype: object
# ID                          22
# Income                   65324
# Age                         66
# Education Status           PhD
# Marital Status         Married
# Kidhome                      0
# Teenhome                     1
# Recency                      0
# MntWines                   384
# MntFruits                    0
# MntMeatProducts            102
# MntFishProducts             21
# MntSweetProducts            32
# MntGoldProds                 5
# NumDealsPurchases            3
# NumWebPurchases              6
# NumCatalogPurchases          2
# NumStorePurchases            9
# NumWebVisitsMonth            4
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2328
# MntTotal                   539
# MntRegularProds            534
# AcceptedCmpOverall           0
# Name: 22, dtype: object
# ID                             23
# Income                      40689
# Age                            69
# Education Status       Graduation
# Marital Status           Together
# Kidhome                         0
# Teenhome                        1
# Recency                        69
# MntWines                      270
# MntFruits                       3
# MntMeatProducts                27
# MntFishProducts                39
# MntSweetProducts                6
# MntGoldProds                   99
# NumDealsPurchases               7
# NumWebPurchases                 7
# NumCatalogPurchases             1
# NumStorePurchases               5
# NumWebVisitsMonth               8
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2627
# MntTotal                      345
# MntRegularProds               246
# AcceptedCmpOverall              0
# Name: 23, dtype: object
# ID                             24
# Income                      18589
# Age                            51
# Education Status       Graduation
# Marital Status             Single
# Kidhome                         0
# Teenhome                        0
# Recency                        89
# MntWines                        6
# MntFruits                       4
# MntMeatProducts                25
# MntFishProducts                15
# MntSweetProducts               12
# MntGoldProds                   13
# NumDealsPurchases               2
# NumWebPurchases                 2
# NumCatalogPurchases             1
# NumStorePurchases               3
# NumWebVisitsMonth               7
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2702
# MntTotal                       62
# MntRegularProds                49
# AcceptedCmpOverall              0
# Name: 24, dtype: object
# ID                             25
# Income                      53359
# Age                            44
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         1
# Teenhome                        1
# Recency                         4
# MntWines                      173
# MntFruits                       4
# MntMeatProducts                30
# MntFishProducts                 3
# MntSweetProducts                6
# MntGoldProds                   41
# NumDealsPurchases               4
# NumWebPurchases                 5
# NumCatalogPurchases             1
# NumStorePurchases               4
# NumWebVisitsMonth               7
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2557
# MntTotal                      216
# MntRegularProds               175
# AcceptedCmpOverall              0
# Name: 25, dtype: object
# ID                             26
# Income                      38360
# Age                            31
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         1
# Teenhome                        0
# Recency                        26
# MntWines                       36
# MntFruits                       2
# MntMeatProducts                42
# MntFishProducts                20
# MntSweetProducts               21
# MntGoldProds                   10
# NumDealsPurchases               2
# NumWebPurchases                 2
# NumCatalogPurchases             1
# NumStorePurchases               4
# NumWebVisitsMonth               3
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2553
# MntTotal                      121
# MntRegularProds               111
# AcceptedCmpOverall              0
# Name: 26, dtype: object
# ID                          27
# Income                   84618
# Age                         55
# Education Status           PhD
# Marital Status         Married
# Kidhome                      0
# Teenhome                     0
# Recency                     96
# MntWines                   684
# MntFruits                  100
# MntMeatProducts            801
# MntFishProducts             21
# MntSweetProducts            66
# MntGoldProds                 0
# NumDealsPurchases            1
# NumWebPurchases              6
# NumCatalogPurchases          9
# NumStorePurchases           10
# NumWebVisitsMonth            2
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 1
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2378
# MntTotal                  1672
# MntRegularProds           1672
# AcceptedCmpOverall           1
# Name: 27, dtype: object
# ID                           28
# Income                    10979
# Age                          31
# Education Status         Master
# Marital Status         Divorced
# Kidhome                       0
# Teenhome                      0
# Recency                      34
# MntWines                      8
# MntFruits                     4
# MntMeatProducts              10
# MntFishProducts               2
# MntSweetProducts              2
# MntGoldProds                  4
# NumDealsPurchases             2
# NumWebPurchases               3
# NumCatalogPurchases           0
# NumStorePurchases             3
# NumWebVisitsMonth             5
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2197
# MntTotal                     26
# MntRegularProds              22
# AcceptedCmpOverall            0
# Name: 28, dtype: object
# ID                           29
# Income                    38620
# Age                          57
# Education Status         Master
# Marital Status         Together
# Kidhome                       0
# Teenhome                      0
# Recency                      56
# MntWines                    112
# MntFruits                    17
# MntMeatProducts              44
# MntFishProducts              34
# MntSweetProducts             22
# MntGoldProds                 89
# NumDealsPurchases             1
# NumWebPurchases               2
# NumCatalogPurchases           5
# NumStorePurchases             3
# NumWebVisitsMonth             3
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2573
# MntTotal                    229
# MntRegularProds             140
# AcceptedCmpOverall            0
# Name: 29, dtype: object
# ID                             30
# Income                      40548
# Age                            50
# Education Status       Graduation
# Marital Status           Together
# Kidhome                         0
# Teenhome                        1
# Recency                        31
# MntWines                      110
# MntFruits                       0
# MntMeatProducts                 5
# MntFishProducts                 2
# MntSweetProducts                0
# MntGoldProds                    3
# NumDealsPurchases               2
# NumWebPurchases                 2
# NumCatalogPurchases             1
# NumStorePurchases               4
# NumWebVisitsMonth               5
# AcceptedCmp3                    0
# AcceptedCmp4                    1
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2786
# MntTotal                      117
# MntRegularProds               114
# AcceptedCmpOverall              1
# Name: 30, dtype: object
# ID                           31
# Income                    46610
# Age                          68
# Education Status            PhD
# Marital Status         Divorced
# Kidhome                       0
# Teenhome                      2
# Recency                       8
# MntWines                     96
# MntFruits                    12
# MntMeatProducts              96
# MntFishProducts              33
# MntSweetProducts             22
# MntGoldProds                 43
# NumDealsPurchases             6
# NumWebPurchases               4
# NumCatalogPurchases           1
# NumStorePurchases             6
# NumWebVisitsMonth             6
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      1
# Customer_Days              2767
# MntTotal                    259
# MntRegularProds             216
# AcceptedCmpOverall            0
# Name: 31, dtype: object
# ID                          32
# Income                   68657
# Age                         74
# Education Status        Master
# Marital Status         Married
# Kidhome                      0
# Teenhome                     0
# Recency                      4
# MntWines                   482
# MntFruits                   34
# MntMeatProducts            471
# MntFishProducts            119
# MntSweetProducts            68
# MntGoldProds                22
# NumDealsPurchases            1
# NumWebPurchases              3
# NumCatalogPurchases          5
# NumStorePurchases            9
# NumWebVisitsMonth            7
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2653
# MntTotal                  1174
# MntRegularProds           1152
# AcceptedCmpOverall           0
# Name: 32, dtype: object
# ID                         33
# Income                  49389
# Age                        69
# Education Status       Master
# Marital Status         Single
# Kidhome                     1
# Teenhome                    1
# Recency                    55
# MntWines                   40
# MntFruits                   0
# MntMeatProducts            19
# MntFishProducts             2
# MntSweetProducts            1
# MntGoldProds                3
# NumDealsPurchases           1
# NumWebPurchases             2
# NumCatalogPurchases         0
# NumStorePurchases           3
# NumWebVisitsMonth           7
# AcceptedCmp3                0
# AcceptedCmp4                0
# AcceptedCmp5                0
# AcceptedCmp1                0
# AcceptedCmp2                0
# Complain                    0
# Z_CostContact               3
# Z_Revenue                  11
# Response                    0
# Customer_Days            2463
# MntTotal                   62
# MntRegularProds            59
# AcceptedCmpOverall          0
# Name: 33, dtype: object
# ID                          34
# Income                   67353
# Age                         50
# Education Status           PhD
# Marital Status         Married
# Kidhome                      0
# Teenhome                     1
# Recency                     37
# MntWines                   702
# MntFruits                   17
# MntMeatProducts            151
# MntFishProducts              0
# MntSweetProducts             8
# MntGoldProds                35
# NumDealsPurchases            5
# NumWebPurchases              5
# NumCatalogPurchases          6
# NumStorePurchases           12
# NumWebVisitsMonth            2
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2339
# MntTotal                   878
# MntRegularProds            843
# AcceptedCmpOverall           0
# Name: 34, dtype: object
# ID                           35
# Income                    23718
# Age                          44
# Education Status       2n Cycle
# Marital Status          Married
# Kidhome                       1
# Teenhome                      0
# Recency                      76
# MntWines                      6
# MntFruits                     3
# MntMeatProducts              14
# MntFishProducts              15
# MntSweetProducts              7
# MntGoldProds                 36
# NumDealsPurchases             3
# NumWebPurchases               3
# NumCatalogPurchases           1
# NumStorePurchases             2
# NumWebVisitsMonth             7
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2459
# MntTotal                     45
# MntRegularProds               9
# AcceptedCmpOverall            0
# Name: 35, dtype: object
# ID                             36
# Income                      42429
# Age                            47
# Education Status       Graduation
# Marital Status              Widow
# Kidhome                         0
# Teenhome                        1
# Recency                        99
# MntWines                       55
# MntFruits                       0
# MntMeatProducts                 6
# MntFishProducts                 2
# MntSweetProducts                0
# MntGoldProds                    4
# NumDealsPurchases               2
# NumWebPurchases                 1
# NumCatalogPurchases             1
# NumStorePurchases               3
# NumWebVisitsMonth               5
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2297
# MntTotal                       63
# MntRegularProds                59
# AcceptedCmpOverall              0
# Name: 36, dtype: object
# ID                           37
# Income                    48948
# Age                          77
# Education Status            PhD
# Marital Status         Divorced
# Kidhome                       0
# Teenhome                      0
# Recency                      53
# MntWines                    437
# MntFruits                     8
# MntMeatProducts             206
# MntFishProducts             160
# MntSweetProducts             49
# MntGoldProds                 42
# NumDealsPurchases             2
# NumWebPurchases               7
# NumCatalogPurchases          10
# NumStorePurchases             5
# NumWebVisitsMonth             6
# AcceptedCmp3                  1
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      1
# Customer_Days              2672
# MntTotal                    860
# MntRegularProds             818
# AcceptedCmpOverall            1
# Name: 37, dtype: object
# ID                             38
# Income                      80011
# Age                            40
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         0
# Teenhome                        1
# Recency                         3
# MntWines                      421
# MntFruits                      76
# MntMeatProducts               536
# MntFishProducts                82
# MntSweetProducts              178
# MntGoldProds                  102
# NumDealsPurchases               2
# NumWebPurchases                 8
# NumCatalogPurchases             6
# NumStorePurchases               5
# NumWebVisitsMonth               4
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2585
# MntTotal                     1293
# MntRegularProds              1191
# AcceptedCmpOverall              0
# Name: 38, dtype: object
# ID                          39
# Income                   20559
# Age                         35
# Education Status        Master
# Marital Status         Married
# Kidhome                      1
# Teenhome                     0
# Recency                     88
# MntWines                    13
# MntFruits                    1
# MntMeatProducts             29
# MntFishProducts              3
# MntSweetProducts             0
# MntGoldProds                 7
# NumDealsPurchases            2
# NumWebPurchases              2
# NumCatalogPurchases          0
# NumStorePurchases            3
# NumWebVisitsMonth            8
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2633
# MntTotal                    46
# MntRegularProds             39
# AcceptedCmpOverall           0
# Name: 39, dtype: object
# ID                             40
# Income                      21994
# Age                            63
# Education Status       Graduation
# Marital Status           Together
# Kidhome                         0
# Teenhome                        1
# Recency                         4
# MntWines                        9
# MntFruits                       0
# MntMeatProducts                 6
# MntFishProducts                 3
# MntSweetProducts                1
# MntGoldProds                    3
# NumDealsPurchases               1
# NumWebPurchases                 0
# NumCatalogPurchases             0
# NumStorePurchases               3
# NumWebVisitsMonth               5
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2711
# MntTotal                       19
# MntRegularProds                16
# AcceptedCmpOverall              0
# Name: 40, dtype: object
# ID                          41
# Income                    7500
# Age                         45
# Education Status        Master
# Marital Status         Married
# Kidhome                      1
# Teenhome                     0
# Recency                     19
# MntWines                     3
# MntFruits                    1
# MntMeatProducts             10
# MntFishProducts              3
# MntSweetProducts             2
# MntGoldProds                12
# NumDealsPurchases            3
# NumWebPurchases              2
# NumCatalogPurchases          0
# NumStorePurchases            3
# NumWebVisitsMonth            5
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2429
# MntTotal                    19
# MntRegularProds              7
# AcceptedCmpOverall           0
# Name: 41, dtype: object
# ID                             42
# Income                      79941
# Age                            44
# Education Status       Graduation
# Marital Status             Single
# Kidhome                         0
# Teenhome                        0
# Recency                        72
# MntWines                      123
# MntFruits                     164
# MntMeatProducts               266
# MntFishProducts               227
# MntSweetProducts               30
# MntGoldProds                  174
# NumDealsPurchases               1
# NumWebPurchases                 2
# NumCatalogPurchases             4
# NumStorePurchases               9
# NumWebVisitsMonth               1
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2160
# MntTotal                      810
# MntRegularProds               636
# AcceptedCmpOverall              0
# Name: 42, dtype: object
# ID                           43
# Income                     7500
# Age                          24
# Education Status       2n Cycle
# Marital Status          Married
# Kidhome                       0
# Teenhome                      0
# Recency                      24
# MntWines                      3
# MntFruits                    18
# MntMeatProducts              14
# MntFishProducts              15
# MntSweetProducts             22
# MntGoldProds                 50
# NumDealsPurchases             3
# NumWebPurchases               3
# NumCatalogPurchases           1
# NumStorePurchases             3
# NumWebVisitsMonth             9
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      1
# Customer_Days              2756
# MntTotal                     72
# MntRegularProds              22
# AcceptedCmpOverall            0
# Name: 43, dtype: object
# ID                             44
# Income                      41728
# Age                            52
# Education Status       Graduation
# Marital Status           Together
# Kidhome                         1
# Teenhome                        0
# Recency                        92
# MntWines                       13
# MntFruits                       6
# MntMeatProducts                15
# MntFishProducts                 3
# MntSweetProducts                5
# MntGoldProds                   13
# NumDealsPurchases               1
# NumWebPurchases                 2
# NumCatalogPurchases             0
# NumStorePurchases               2
# NumWebVisitsMonth              10
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2560
# MntTotal                       42
# MntRegularProds                29
# AcceptedCmpOverall              0
# ...
# Kidhome                      1
# Teenhome                     2
# Recency                     33
# MntWines                    21
# MntFruits                   12
# MntMeatProducts             12
# MntFishProducts              0
# MntSweetProducts             3
# MntGoldProds                 3
# NumDealsPurchases            3
# NumWebPurchases              2
# NumCatalogPurchases          0
# NumStorePurchases            4
# NumWebVisitsMonth            4
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     0
# Customer_Days             2163
# MntTotal                    48
# MntRegularProds             45
# AcceptedCmpOverall           0
# Name: 2190, dtype: object
# ID                       2191
# Income                  57642
# Age                        50
# Education Status          PhD
# Marital Status         Single
# Kidhome                     0
# Teenhome                    1
# Recency                    24
# MntWines                  580
# MntFruits                   6
# MntMeatProducts            58
# MntFishProducts             8
# MntSweetProducts            0
# MntGoldProds               27
# NumDealsPurchases           3
# NumWebPurchases             7
# NumCatalogPurchases         6
# NumStorePurchases           6
# NumWebVisitsMonth           4
# AcceptedCmp3                1
# AcceptedCmp4                0
# AcceptedCmp5                0
# AcceptedCmp1                0
# AcceptedCmp2                0
# Complain                    0
# Z_CostContact               3
# Z_Revenue                  11
# Response                    0
# Customer_Days            2330
# MntTotal                  652
# MntRegularProds           625
# AcceptedCmpOverall          1
# Name: 2191, dtype: object
# ID                           2192
# Income                      58554
# Age                            52
# Education Status       Graduation
# Marital Status           Together
# Kidhome                         1
# Teenhome                        1
# Recency                        55
# MntWines                      368
# MntFruits                      24
# MntMeatProducts                68
# MntFishProducts                38
# MntSweetProducts                0
# MntGoldProds                   88
# NumDealsPurchases               6
# NumWebPurchases                 8
# NumCatalogPurchases             2
# NumStorePurchases               6
# NumWebVisitsMonth               7
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2800
# MntTotal                      498
# MntRegularProds               410
# AcceptedCmpOverall              0
# Name: 2192, dtype: object
# ID                           2193
# Income                      63777
# Age                            41
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         1
# Teenhome                        1
# Recency                        87
# MntWines                      457
# MntFruits                       5
# MntMeatProducts               106
# MntFishProducts                15
# MntSweetProducts               17
# MntGoldProds                   53
# NumDealsPurchases               8
# NumWebPurchases                11
# NumCatalogPurchases             1
# NumStorePurchases               6
# NumWebVisitsMonth               8
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2621
# MntTotal                      600
# MntRegularProds               547
# AcceptedCmpOverall              0
# Name: 2193, dtype: object
# ID                           2194
# Income                      57967
# Age                            58
# Education Status       Graduation
# Marital Status             Single
# Kidhome                         0
# Teenhome                        1
# Recency                        39
# MntWines                      229
# MntFruits                       7
# MntMeatProducts               137
# MntFishProducts                 4
# MntSweetProducts                0
# MntGoldProds                   91
# NumDealsPurchases               5
# NumWebPurchases                 4
# NumCatalogPurchases             2
# NumStorePurchases               8
# NumWebVisitsMonth               5
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2642
# MntTotal                      377
# MntRegularProds               286
# AcceptedCmpOverall              0
# Name: 2194, dtype: object
# ID                           2195
# Income                      24434
# Age                            48
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         2
# Teenhome                        0
# Recency                         9
# MntWines                        3
# MntFruits                       2
# MntMeatProducts                 8
# MntFishProducts                20
# MntSweetProducts                0
# MntGoldProds                   17
# NumDealsPurchases               2
# NumWebPurchases                 2
# NumCatalogPurchases             1
# NumStorePurchases               2
# NumWebVisitsMonth               7
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2201
# MntTotal                       33
# MntRegularProds                16
# AcceptedCmpOverall              0
# Name: 2195, dtype: object
# ID                           2196
# Income                      11012
# Age                            36
# Education Status       Graduation
# Marital Status             Single
# Kidhome                         1
# Teenhome                        0
# Recency                        82
# MntWines                       24
# MntFruits                       3
# MntMeatProducts                26
# MntFishProducts                 7
# MntSweetProducts                1
# MntGoldProds                   23
# NumDealsPurchases               3
# NumWebPurchases                 3
# NumCatalogPurchases             1
# NumStorePurchases               2
# NumWebVisitsMonth               9
# AcceptedCmp3                    1
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2629
# MntTotal                       61
# MntRegularProds                38
# AcceptedCmpOverall              1
# Name: 2196, dtype: object
# ID                       2197
# Income                  44802
# Age                        50
# Education Status       Master
# Marital Status         Single
# Kidhome                     0
# Teenhome                    0
# Recency                    71
# MntWines                  853
# MntFruits                  10
# MntMeatProducts           143
# MntFishProducts            13
# MntSweetProducts           10
# MntGoldProds               20
# NumDealsPurchases           2
# NumWebPurchases             9
# NumCatalogPurchases         4
# NumStorePurchases          12
# NumWebVisitsMonth           8
# AcceptedCmp3                0
# AcceptedCmp4                0
# AcceptedCmp5                0
# AcceptedCmp1                0
# AcceptedCmp2                0
# Complain                    0
# Z_CostContact               3
# Z_Revenue                  11
# Response                    0
# Customer_Days            2836
# MntTotal                 1029
# MntRegularProds          1009
# AcceptedCmpOverall          0
# Name: 2197, dtype: object
# ID                           2198
# Income                      26816
# Age                            34
# Education Status       Graduation
# Marital Status             Single
# Kidhome                         0
# Teenhome                        0
# Recency                        50
# MntWines                        5
# MntFruits                       1
# MntMeatProducts                 6
# MntFishProducts                 3
# MntSweetProducts                4
# MntGoldProds                    3
# NumDealsPurchases               1
# NumWebPurchases                 0
# NumCatalogPurchases             0
# NumStorePurchases               3
# NumWebVisitsMonth               4
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2840
# MntTotal                       19
# MntRegularProds                16
# AcceptedCmpOverall              0
# Name: 2198, dtype: object
# ID                           2199
# Income                      34421
# Age                            46
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         1
# Teenhome                        0
# Recency                        81
# MntWines                        3
# MntFruits                       3
# MntMeatProducts                 7
# MntFishProducts                 6
# MntSweetProducts                2
# MntGoldProds                    9
# NumDealsPurchases               1
# NumWebPurchases                 1
# NumCatalogPurchases             0
# NumStorePurchases               2
# NumWebVisitsMonth               7
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2522
# MntTotal                       21
# MntRegularProds                12
# AcceptedCmpOverall              0
# Name: 2199, dtype: object
# ID                           2200
# Income                      61223
# Age                            53
# Education Status       Graduation
# Marital Status            Married
# Kidhome                         0
# Teenhome                        1
# Recency                        46
# MntWines                      709
# MntFruits                      43
# MntMeatProducts               182
# MntFishProducts                42
# MntSweetProducts              118
# MntGoldProds                  247
# NumDealsPurchases               2
# NumWebPurchases                 9
# NumCatalogPurchases             3
# NumStorePurchases               4
# NumWebVisitsMonth               5
# AcceptedCmp3                    0
# AcceptedCmp4                    0
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2540
# MntTotal                     1094
# MntRegularProds               847
# AcceptedCmpOverall              0
# Name: 2200, dtype: object
# ID                         2201
# Income                    64014
# Age                          74
# Education Status            PhD
# Marital Status         Together
# Kidhome                       2
# Teenhome                      1
# Recency                      56
# MntWines                    406
# MntFruits                     0
# MntMeatProducts              30
# MntFishProducts               0
# MntSweetProducts              0
# MntGoldProds                  8
# NumDealsPurchases             7
# NumWebPurchases               8
# NumCatalogPurchases           2
# NumStorePurchases             5
# NumWebVisitsMonth             7
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  1
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2178
# MntTotal                    436
# MntRegularProds             428
# AcceptedCmpOverall            1
# Name: 2201, dtype: object
# ID                           2202
# Income                      56981
# Age                            39
# Education Status       Graduation
# Marital Status           Divorced
# Kidhome                         0
# Teenhome                        0
# Recency                        91
# MntWines                      908
# MntFruits                      48
# MntMeatProducts               217
# MntFishProducts                32
# MntSweetProducts               12
# MntGoldProds                   24
# NumDealsPurchases               1
# NumWebPurchases                 2
# NumCatalogPurchases             3
# NumStorePurchases              13
# NumWebVisitsMonth               6
# AcceptedCmp3                    0
# AcceptedCmp4                    1
# AcceptedCmp5                    0
# AcceptedCmp1                    0
# AcceptedCmp2                    0
# Complain                        0
# Z_CostContact                   3
# Z_Revenue                      11
# Response                        0
# Customer_Days                2314
# MntTotal                     1217
# MntRegularProds              1193
# AcceptedCmpOverall              1
# Name: 2202, dtype: object
# ID                         2203
# Income                    69245
# Age                          64
# Education Status         Master
# Marital Status         Together
# Kidhome                       0
# Teenhome                      1
# Recency                       8
# MntWines                    428
# MntFruits                    30
# MntMeatProducts             214
# MntFishProducts              80
# MntSweetProducts             30
# MntGoldProds                 61
# NumDealsPurchases             2
# NumWebPurchases               6
# NumCatalogPurchases           5
# NumStorePurchases            10
# NumWebVisitsMonth             3
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0
# Customer_Days              2315
# MntTotal                    782
# MntRegularProds             721
# AcceptedCmpOverall            0
# Name: 2203, dtype: object
# ID                        2204
# Income                   52869
# Age                         66
# Education Status           PhD
# Marital Status         Married
# Kidhome                      1
# Teenhome                     1
# Recency                     40
# MntWines                    84
# MntFruits                    3
# MntMeatProducts             61
# MntFishProducts              2
# MntSweetProducts             1
# MntGoldProds                21
# NumDealsPurchases            3
# NumWebPurchases              3
# NumCatalogPurchases          1
# NumStorePurchases            4
# NumWebVisitsMonth            7
# AcceptedCmp3                 0
# AcceptedCmp4                 0
# AcceptedCmp5                 0
# AcceptedCmp1                 0
# AcceptedCmp2                 0
# Complain                     0
# Z_CostContact                3
# Z_Revenue                   11
# Response                     1
# Customer_Days             2781
# MntTotal                   151
# MntRegularProds            130
# AcceptedCmpOverall           0
# Name: 2204, dtype: object
