# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import requests
import pandas as pd
import time

# %%
URL = 'https://www.scrapethissite.com/pages/forms/'

page = requests.get(URL)
html = page.content
soup = BeautifulSoup(html, "html.parser")

# %%
table = soup.find("table",class_="table")

# %%
columns = soup.find_all('th')

titles = ()

def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '',text)

for i in columns:
    x = remove_html_tags(str(i))
    l = list(titles)
    if x != "None":
        t = x.replace('\n', '')
        l.append(t)
        titles = tuple(l)

# %%
df = pd.DataFrame(columns=['Team Name','Year','Wins','Losses','OT Losses','Win %','Goals For','Goals Against','+/-'])

# %%
for r in table.find_all('tr'):
     cols = r.find_all('td')
     
     
     if (cols != []):
         name = remove_html_tags(str(cols[0])).replace('\n','').replace(' ','')
         year = remove_html_tags(str(cols[1])).replace('\n','')
         wins = remove_html_tags(str(cols[2])).replace('\n','')
         losses = remove_html_tags(str(cols[3])).replace('\n','')
         ot = remove_html_tags(str(cols[4])).replace('\n','')
         winPerc = remove_html_tags(str(cols[5])).replace('\n','')
         gf = remove_html_tags(str(cols[6])).replace('\n','')
         ga = remove_html_tags(str(cols[7])).replace('\n','')
         over_under = remove_html_tags(str(cols[8])).replace('\n','')
         
         df = pd.concat([df, pd.DataFrame.from_records([{'Team Name': name, 'Year': year, 'Wins': wins, 'Losses': losses, 'OT Losses': ot, 'Win %': winPerc, 'Goals For': gf, 'Goals Against': ga, '+/-':over_under}])], ignore_index=True)

# %%
df.to_csv('test.csv')

# %%
#new = df[(df['Win %'].astype(float) >= 0.50).all()]

df['Win %'].astype(float)

df['Win %'].dtype


df.loc[(df['Win %'].astype(float) >= 0.50) & (df['Goals Against'].astype(int) >= 300)]
# Out:
#              Team Name                                               Year  \
# 14  PittsburghPenguins                              1990              ...
#
#                                                  Wins  \
# 14                              41                ...
#
#                                                Losses OT Losses  \
# 14                              33                ...
#
#                                                 Win %  \
# 14                              0.512             ...
#
#                                             Goals For  \
# 14                              342               ...
#
#                                         Goals Against  \
# 14                              305               ...
#
#                                                   +/-
# 14                              37                ...

# %%
df.sort_values(by='Goals Against', ascending=False)
# Out:
#               Team Name                                               Year  \
# 15      QuebecNordiques                              1990              ...
# 17    TorontoMapleLeafs                              1990              ...
# 18     VancouverCanucks                              1990              ...
# 23        CalgaryFlames                              1991              ...
# 14   PittsburghPenguins                              1990              ...
# 22        BuffaloSabres                              1991              ...
# 4       DetroitRedWings                              1990              ...
# 11     NewYorkIslanders                              1990              ...
# 20         WinnipegJets                              1990              ...
# 1         BuffaloSabres                              1990              ...
# 6       HartfordWhalers                              1990              ...
# 21         BostonBruins                              1991              ...
# 5        EdmontonOilers                              1990              ...
# 13   PhiladelphiaFlyers                              1990              ...
# 8   MinnesotaNorthStars                              1990              ...
# 12       NewYorkRangers                              1990              ...
# 0          BostonBruins                              1990              ...
# 10      NewJerseyDevils                              1990              ...
# 2         CalgaryFlames                              1990              ...
# 19   WashingtonCapitals                              1990              ...
# 7       LosAngelesKings                              1990              ...
# 16        St.LouisBlues                              1990              ...
# 9     MontrealCanadiens                              1990              ...
# 24    ChicagoBlackhawks                              1991              ...
# 3     ChicagoBlackhawks                              1990              ...
#
#                                                  Wins  \
# 15                              16                ...
# 17                              23                ...
# 18                              28                ...
# 23                              31                ...
# 14                              41                ...
# 22                              31                ...
# 4                               34                ...
# 11                              25                ...
# 20                              26                ...
# 1                               31                ...
# 6                               31                ...
# 21                              36                ...
# 5                               37                ...
# 13                              33                ...
# 8                               27                ...
# 12                              36                ...
# 0                               44                ...
# 10                              32                ...
# 2                               46                ...
# 19                              37                ...
# 7                               46                ...
# 16                              47                ...
# 9                               39                ...
# 24                              36                ...
# 3                               49                ...
#
#                                                Losses OT Losses  \
# 15                              50                ...
# 17                              46                ...
# 18                              43                ...
# 23                              37                ...
# 14                              33                ...
# 22                              37                ...
# 4                               38                ...
# 11                              45                ...
# 20                              43                ...
# 1                               30                ...
# 6                               38                ...
# 21                              32                ...
# 5                               37                ...
# 13                              37                ...
# 8                               39                ...
# 12                              31                ...
# 0                               24                ...
# 10                              33                ...
# 2                               26                ...
# 19                              36                ...
# 7                               24                ...
# 16                              22                ...
# 9                               30                ...
# 24                              29                ...
# 3                               23                ...
#
#                                                 Win %  \
# 15                              0.2               ...
# 17                              0.287             ...
# 18                              0.35              ...
# 23                              0.388             ...
# 14                              0.512             ...
# 22                              0.388             ...
# 4                               0.425             ...
# 11                              0.312             ...
# 20                              0.325             ...
# 1                               0.388             ...
# 6                               0.388             ...
# 21                              0.45              ...
# 5                               0.463             ...
# 13                              0.412             ...
# 8                               0.338             ...
# 12                              0.45              ...
# 0                               0.55              ...
# 10                              0.4               ...
# 2                               0.575             ...
# 19                              0.463             ...
# 7                               0.575             ...
# 16                              0.588             ...
# 9                               0.487             ...
# 24                              0.45              ...
# 3                               0.613             ...
#
#                                             Goals For  \
# 15                              236               ...
# 17                              241               ...
# 18                              243               ...
# 23                              296               ...
# 14                              342               ...
# 22                              289               ...
# 4                               273               ...
# 11                              223               ...
# 20                              260               ...
# 1                               292               ...
# 6                               238               ...
# 21                              270               ...
# 5                               272               ...
# 13                              252               ...
# 8                               256               ...
# 12                              297               ...
# 0                               299               ...
# 10                              272               ...
# 2                               344               ...
# 19                              258               ...
# 7                               340               ...
# 16                              310               ...
# 9                               273               ...
# 24                              257               ...
# 3                               284               ...
#
#                                         Goals Against  \
# 15                              354               ...
# 17                              318               ...
# 18                              315               ...
# 23                              305               ...
# 14                              305               ...
# 22                              299               ...
# 4                               298               ...
# 11                              290               ...
# 20                              288               ...
# 1                               278               ...
# 6                               276               ...
# 21                              275               ...
# 5                               272               ...
# 13                              267               ...
# 8                               266               ...
# 12                              265               ...
# 0                               264               ...
# 10                              264               ...
# 2                               263               ...
# 19                              258               ...
# 7                               254               ...
# 16                              250               ...
# 9                               249               ...
# 24                              236               ...
# 3                               211               ...
#
#                                                   +/-
# 15                              -118              ...
# 17                              -77               ...
# 18                              -72               ...
# 23                              -9                ...
# 14                              37                ...
# 22                              -10               ...
# 4                               -25               ...
# 11                              -67               ...
# 20                              -28               ...
# 1                               14                ...
# 6                               -38               ...
# 21                              -5                ...
# 5                               0                 ...
# 13                              -15               ...
# 8                               -10               ...
# 12                              32                ...
# 0                               35                ...
# 10                              8                 ...
# 2                               81                ...
# 19                              0                 ...
# 7                               86                ...
# 16                              60                ...
# 9                               24                ...
# 24                              21                ...
# 3                               73                ...
